# %%
import os
import random
import pandas as pd
import urllib.request
from bs4 import BeautifulSoup

# %%
import socket
socket.setdefaulttimeout(30)

# %%
ARTS_LIST = 'query_results.csv'
DIR = 'data'

ID, CULTURE, URL = range(0, 3)

# %%
with open(ARTS_LIST) as f:
    arts_to_download = f.readlines()
    arts_to_download = [line.strip() for line in arts_to_download]

# %%
data = []

for line in arts_to_download:
    object_id, *culture, url = line.split(',')
    culture = ' '.join(culture)
    data.append((object_id, culture, url))

# %%
data[-3:]
# Out:
# [('157369',
#   'American or European',
#   'http://www.metmuseum.org/art/collection/search/157369'),
#  ('81727',
#   'American or European',
#   'http://www.metmuseum.org/art/collection/search/81727'),
#  ('106645',
#   'American or European',
#   'http://www.metmuseum.org/art/collection/search/106645')]

# %%
data_df = pd.DataFrame(data, columns=['object_id', 'culture', 'url'])
data_df.tail()
# Out:
#     object_id               culture  \
# 245    157610  American or European
# 246    157668  American or European
# 247    157369  American or European
# 248     81727  American or European
# 249    106645  American or European
#
#                                                    url
# 245  http://www.metmuseum.org/art/collection/search...
# 246  http://www.metmuseum.org/art/collection/search...
# 247  http://www.metmuseum.org/art/collection/search...
# 248  http://www.metmuseum.org/art/collection/search...
# 249  http://www.metmuseum.org/art/collection/search...

# %%
data_df.groupby('culture').count().sort_values(by='object_id', ascending=False)
# Out:
#                                     object_id  url
# culture
# Japan                                     125  125
# American or European                       61   61
# China                                      50   50
# Tibet                                       3    3
# "French,  Paris"                            2    2
# Indian (Gujerat)                            2    2
# Japan (Ainu)                                2    2
# "Japan (Okinawa,  Ry奴ky奴 Islands)"          1    1
# French                                      1    1
# Japan (Kyoto)                               1    1
# Japan (Ry奴ky奴 Islands)                      1    1
# Western European                            1    1

# %%
test_url = data[-1][-1]
test_url
# Out:
# 'http://www.metmuseum.org/art/collection/search/106645'

# %%
ua_list = [
    "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.6; rv2.0.1) Gecko/20100101 Firefox/4.0.1",
    "Mozilla/5.0 (Windows NT 6.1; rv2.0.1) Gecko/20100101 Firefox/4.0.1",
    "Opera/9.8.0 (Macintosh; Intel Mac OS X 10.6.8; U; en) Presto/2.8.131 Version/11.11",
    "Opera/9.8.0 (Windows NT 6.1; U; en) Presto/2.8.131 Version/11.11",
    "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_0) AppleWebKit/535.11 (LHTML, like Gecko) Chrome/17"
]

user_agent = random.choice(ua_list)
request = urllib.request.Request(test_url)
request.add_header("User-Agent", user_agent)

response = urllib.request.urlopen(request, timeout=5)
encoding = response.headers.get_content_charset()

# %%
html = response.read().decode(encoding)
soup = BeautifulSoup(html)

# %%
finds_list = soup.find_all("a", class_="gtm__download__image")

# %%
for a in finds_list:
    print(a['href'])
# Out:
# https://images.metmuseum.org/CRDImages/ci/original/C.I.39.112.3_F.jpg

# %%
def get_download_link(art_page):
    '''
    find the download links of the art given the museum page
    
    :type str: art_page
    :rtype list of str
    '''
    
    ua_list = [
        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.6; rv2.0.1) Gecko/20100101 Firefox/4.0.1",
        "Mozilla/5.0 (Windows NT 6.1; rv2.0.1) Gecko/20100101 Firefox/4.0.1",
        "Opera/9.8.0 (Macintosh; Intel Mac OS X 10.6.8; U; en) Presto/2.8.131 Version/11.11",
        "Opera/9.8.0 (Windows NT 6.1; U; en) Presto/2.8.131 Version/11.11",
        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_0) AppleWebKit/535.11 (LHTML, like Gecko) Chrome/17"
    ]
    
    user_agent = random.choice(ua_list)
    request = urllib.request.Request(art_page)
    request.add_header("User-Agent", user_agent)

    try:
        response = urllib.request.urlopen(request, timeout=5)
        encoding = response.headers.get_content_charset()
    
        if not encoding:
            return []
    
        html = response.read().decode(encoding)
        soup = BeautifulSoup(html)
        finds_list = soup.find_all("a", class_="gtm__download__image")
    
        return [a['href'] for a in finds_list]
    
    except:
        return []

# %%
data[-1][-1]
# Out:
# 'http://www.metmuseum.org/art/collection/search/106645'

# %%
get_download_link(data[-1][-1])
# Out:
# []

# %%
for index, row in enumerate(data[88:]):
    print("processing image {} ...".format(index))
    i = 0
    
    for img_link in get_download_link(row[URL]):
        print('image linked retrived, ', img_link)
        
        save_folder = os.path.join(DIR, row[CULTURE])
        file_name = os.path.join(save_folder, "{}-{}.jpg".format(row[ID], i))
        if not os.path.exists(save_folder):
            os.makedirs(save_folder)
        print(file_name)
    
        try:
            urllib.request.urlretrieve(img_link, file_name)
            print('file saved.')
            print('-' * 20)
            i += 1
        
        except:
            pass
# Out:
# processing image 0 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/as/original/RT751.jpg
# data\Japan\44946-0.jpg
# processing image 1 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/as/original/DP330788.jpg
# data\Japan\45387-0.jpg
# file saved.
# --------------------
# processing image 2 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/as/original/184622.jpg
# data\Japan\55963-0.jpg
# file saved.
# --------------------
# processing image 3 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/as/original/178214.jpg
# data\Japan\55965-0.jpg
# file saved.
# --------------------
# processing image 4 ...
# processing image 5 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/as/original/DT204734.jpg
# data\Japan\50803-0.jpg
# file saved.
# --------------------
# processing image 6 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/as/original/DT11467.jpg
# data\Japan\55960-0.jpg
# file saved.
# --------------------
# processing image 7 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/as/original/DT10413.jpg
# data\Japan\45399-0.jpg
# file saved.
# --------------------
# processing image 8 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/as/original/DP277712.jpg
# data\Japan\65352-0.jpg
# file saved.
# --------------------
# processing image 9 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/as/original/DT340530.jpg
# data\Japan\45386-0.jpg
# file saved.
# --------------------
# processing image 10 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/as/original/DP277701.jpg
# data\Japan\65353-0.jpg
# file saved.
# --------------------
# processing image 11 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/as/original/DT2914.jpg
# data\Japan\65354-0.jpg
# file saved.
# --------------------
# processing image 12 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/as/original/DP217601.jpg
# data\Japan\45198-0.jpg
# file saved.
# --------------------
# processing image 13 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/as/original/86940.jpg
# data\Japan\65356-0.jpg
# file saved.
# --------------------
# processing image 14 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/as/original/DP261421.jpg
# data\Japan\65357-0.jpg
# file saved.
# --------------------
# processing image 15 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/as/original/DP330565.jpg
# data\Japan\45185-0.jpg
# file saved.
# --------------------
# processing image 16 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/as/original/DT204737.jpg
# data\Japan\61198-0.jpg
# file saved.
# --------------------
# processing image 17 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/as/original/DP261415.jpg
# data\Japan\70233-0.jpg
# file saved.
# --------------------
# processing image 18 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/as/original/3910.jpg
# data\Japan\65617-0.jpg
# file saved.
# --------------------
# processing image 19 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/as/original/D
...
# image linked retrived,  https://images.metmuseum.org/CRDImages/as/original/DP157068.jpg
# data\Japan\49822-0.jpg
# file saved.
# --------------------
# processing image 98 ...
# processing image 99 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/as/original/91_1_59_F.JPG
# data\Japan\65755-0.jpg
# file saved.
# --------------------
# processing image 100 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/as/original/DP330771.jpg
# data\Japan\65364-0.jpg
# file saved.
# --------------------
# processing image 101 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/1977.24_F.jpg
# data\American or European\103888-0.jpg
# file saved.
# --------------------
# processing image 102 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/1979.66_F.jpg
# data\American or European\107615-0.jpg
# file saved.
# --------------------
# processing image 103 ...
# processing image 104 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/08.187.1_F.jpg
# data\American or European\91902-0.jpg
# file saved.
# --------------------
# processing image 105 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/1976.333_F.jpg
# data\American or European\103895-0.jpg
# file saved.
# --------------------
# processing image 106 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/1988.300_F.jpg
# data\American or European\82140-0.jpg
# file saved.
# --------------------
# processing image 107 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/DT1708.jpg
# data\American or European\79704-0.jpg
# file saved.
# --------------------
# processing image 108 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/1983.93.1_F.jpg
# data\American or European\91889-0.jpg
# file saved.
# --------------------
# processing image 109 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/1986.73.3_F.jpg
# data\American or European\107102-0.jpg
# processing image 110 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/CI46.36_F.jpg
# data\American or European\103948-0.jpg
# file saved.
# --------------------
# processing image 111 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/CI49.33_F.jpg
# data\American or European\106964-0.jpg
# file saved.
# --------------------
# processing image 112 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/CI52.44_F.jpg
# data\American or European\106966-0.jpg
# file saved.
# --------------------
# processing image 113 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/CI55.48_F.jpg
# data\American or European\84722-0.jpg
# file saved.
# --------------------
# processing image 114 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/1980.145.4_F.jpg
# data\American or European\91982-0.jpg
# file saved.
# --------------------
# processing image 115 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/DT412.jpg
# data\American or European\81107-0.jpg
# file saved.
# --------------------
# processing image 116 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/1981.380.4_F.jpg
# data\American or European\81786-0.jpg
# file saved.
# --------------------
# processing image 117 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/1982.109.2_F.jpg
# data\American or European\81784-0.jpg
# file saved.
# --------------------
# processing image 118 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/1982.348.3_F.jpg
# data\American or European\106959-0.jpg
# file saved.
# --------------------
# processing image 119 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/C.I.50.8.3_F.jpg
# data\American or European\91906-0.jpg
# file saved.
# --------------------
# processing image 120 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/CI65.1.1_F.jpg
# data\American or European\103967-0.jpg
# file saved.
# --------------------
# processing image 121 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/1982.158.10_F.jpg
# data\American or European\82127-0.jpg
# file saved.
# --------------------
# processing image 122 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/CI37.13.6_F.jpg
# data\American or European\103917-0.jpg
# file saved.
# --------------------
# processing image 123 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/CI41.64.1_F.jpg
# data\American or European\103934-0.jpg
# file saved.
# --------------------
# processing image 124 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/CI48.14.3.JPG
# data\American or European\84053-0.jpg
# file saved.
# --------------------
# processing image 125 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/CI48.37.1_F.jpg
# data\American or European\103950-0.jpg
# file saved.
# --------------------
# processing image 126 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/CI48.41.3_F.jpg
# data\American or European\107109-0.jpg
# file saved.
# --------------------
# processing image 127 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/C.I.49.42.2_F.jpg
# data\American or European\91142-0.jpg
# file saved.
# --------------------
# processing image 128 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/CI52.48.6_F.jpg
# data\American or European\103954-0.jpg
# file saved.
# --------------------
# processing image 129 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/CI53.31.4_F.jpg
# data\American or European\103956-0.jpg
# file saved.
# --------------------
# processing image 130 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/43.133.4_CP4.jpg
# data\American or European\159228-0.jpg
# file saved.
# --------------------
# processing image 131 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/66.101.112_front_CP4.jpg
# data\American or European\159483-0.jpg
# processing image 132 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/81.110.2_CP4.jpg
# data\American or European\159586-0.jpg
# file saved.
# --------------------
# processing image 133 ...
# processing image 134 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/CI38.23.24_F.jpg
# data\American or European\103921-0.jpg
# file saved.
# --------------------
# processing image 135 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/C.I.38.23.36_F.jpg
# data\American or European\91896-0.jpg
# file saved.
# --------------------
# processing image 136 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/C.I.38.23.38_F.jpg
# data\American or European\91898-0.jpg
# file saved.
# --------------------
# processing image 137 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/C.I.38.23.40_F.jpg
# data\American or European\91899-0.jpg
# processing image 138 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/C.I.38.23.49_F.jpg
# data\American or European\91968-0.jpg
# file saved.
# --------------------
# processing image 139 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/C.I.38.23.50_F.jpg
# data\American or European\91969-0.jpg
# file saved.
# --------------------
# processing image 140 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/CI38.63.20_F.jpg
# data\American or European\103925-0.jpg
# file saved.
# --------------------
# processing image 141 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/C.I.39.13.24_F.jpg
# data\American or European\84365-0.jpg
# file saved.
# --------------------
# processing image 142 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/CI39.13.69_F.jpg
# data\American or European\107936-0.jpg
# file saved.
# --------------------
# processing image 143 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/CI40.116.6_F.jpg
# data\American or European\103931-0.jpg
# file saved.
# --------------------
# processing image 144 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/C.I.40.193.1_F.jpg
# data\American or European\91971-0.jpg
# file saved.
# --------------------
# processing image 145 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/CI41.118.4_F.jpg
# data\American or European\108038-0.jpg
# processing image 146 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/C.I.53.72.20_F.jpg
# data\American or European\107840-0.jpg
# file saved.
# --------------------
# processing image 147 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/62.128_CP1.jpg
# data\American or European\157336-0.jpg
# file saved.
# --------------------
# processing image 148 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/61.183_front_CP4.jpg
# data\American or European\157728-0.jpg
# file saved.
# --------------------
# processing image 149 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/65.80.6_CP4.jpg
# data\American or European\158190-0.jpg
# file saved.
# --------------------
# processing image 150 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/21.392_CP2.jpg
# data\American or European\173297-0.jpg
# file saved.
# --------------------
# processing image 151 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/C.I.43.126.28_F.jpg
# data\American or European\107762-0.jpg
# file saved.
# --------------------
# processing image 152 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/1973.195.5_F.jpg
# data\American or European\91914-0.jpg
# file saved.
# --------------------
# processing image 153 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/CI37.13.5ab_F.jpg
# data\American or European\103916-0.jpg
# file saved.
# --------------------
# processing image 154 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/CI39.98.2ab_F.jpg
# data\American or European\103928-0.jpg
# file saved.
# --------------------
# processing image 155 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/CI55.51.5ab_F.jpg
# data\American or European\103959-0.jpg
# file saved.
# --------------------
# processing image 156 ...
# processing image 157 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/49.212a-b_CP4.jpg
# data\American or European\157610-0.jpg
# file saved.
# --------------------
# processing image 158 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/55.207.43a-b_front_CP4.jpg
# data\American or European\157668-0.jpg
# file saved.
# --------------------
# processing image 159 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/65.181.3_CP1.jpg
# data\American or European\157369-0.jpg
# file saved.
# --------------------
# processing image 160 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/C.I.69.24.1_F.jpg
# data\American or European\81727-0.jpg
# processing image 161 ...
# image linked retrived,  https://images.metmuseum.org/CRDImages/ci/original/C.I.39.112.3_F.jpg
# data\American or European\106645-0.jpg
# file saved.
# --------------------
